# %%
import requests
import pandas as pd

# %%
# this function will accept a FIADB-API fullreport URL and return dataframes for the estimates as well as subtotals, and totals where available.
def fiadb_api_GET(url):
    # make request
    resp = requests.get(url)
    # parse response to json
    data = resp.json()

    # create output dictionary and populate it with estimate data frames
    outDict = {}
    # append estimates
    outDict['estimates'] = pd.DataFrame(data['estimates'])

    # append subtotals and totals if present
    if 'subtotals' in data.keys():
        subT = {}
        for i in data['subtotals'].keys():
            subT[i] = pd.DataFrame(data['subtotals'][i])
        outDict['subtotals'] = subT
        outDict['totals'] = pd.DataFrame(data['totals'])

    # append metadata
    outDict['metadata'] = data['metadata']
    return outDict

# %%
# example of usage
url = "https://apps.fs.usda.gov/fiadb-api/fullreport?rselected=County%20code%20and%20name&cselected=Ownership%20class&schema=FS_FIADB.&snum=2&wc=342021&outputFormat=NJSON"
getData = fiadb_api_GET(url=url)

# %%
# estimate data frame
df = getData['estimates']

# %%
df.head()
# Out:
#        ESTIMATE                     GRP1                             GRP2  \
# 0    506.868805  `1773 34001 NJ Atlantic  `0004 Fish and Wildlife Service
# 1   3570.939143  `1773 34001 NJ Atlantic              `0006 Other federal
# 2  59465.501250  `1773 34001 NJ Atlantic                      `0007 State
# 3  46432.619674  `1773 34001 NJ Atlantic       `0008 County and Municipal
# 4  73625.650784  `1773 34001 NJ Atlantic                    `0010 Private
#
#    PLOT_COUNT            SE  SE_PERCENT      VARIANCE
# 0           1    506.868805  100.000000  2.569160e+05
# 1           1   3593.243520  100.624608  1.291140e+07
# 2          21  12981.976202   21.831105  1.685317e+08
# 3          13  12366.672551   26.633588  1.529346e+08
# 4          25  14630.928291   19.872053  2.140641e+08

# %%
df = df.drop(columns = ["PLOT_COUNT", "SE", "SE_PERCENT", "VARIANCE"], axis = 1)

# %%
df["GRP2"] = df["GRP2"].str.split(" ", n = 1).str[1] 

df["GRP1"] = df["GRP1"].str.split(" ", n = 1).str[1]

# %%
df.head()
# Out:
#        ESTIMATE               GRP1                       GRP2
# 0    506.868805  34001 NJ Atlantic  Fish and Wildlife Service
# 1   3570.939143  34001 NJ Atlantic              Other federal
# 2  59465.501250  34001 NJ Atlantic                      State
# 3  46432.619674  34001 NJ Atlantic       County and Municipal
# 4  73625.650784  34001 NJ Atlantic                    Private

# %%
#County code and name 	Total 	National Park Service 	Fish and Wildlife Service 	Dept of Defense 	Other federal 	State 	County and Municipal 	Other local govt 	Private

#return products.melt(id_vars = "product_id", value_vars = ["store1","store2","store3"],  var_name = "store", value_name = "price").dropna()


df = df.pivot(index = "GRP1", columns = "GRP2", values = "ESTIMATE")

# %%
df.head()
# Out:
# GRP2                 County and Municipal  Dept of Defense  \
# GRP1
# 34001 NJ Atlantic            46432.619674              NaN
# 34003 NJ Bergen               3233.604712              NaN
# 34005 NJ Burlington          10965.412506     19626.162081
# 34007 NJ Camden              20728.499223              NaN
# 34009 NJ Cape May              300.403451              NaN
#
# GRP2                 Fish and Wildlife Service  National Park Service  \
# GRP1
# 34001 NJ Atlantic                   506.868805                    NaN
# 34003 NJ Bergen                            NaN                    NaN
# 34005 NJ Burlington                        NaN                    NaN
# 34007 NJ Camden                            NaN                    NaN
# 34009 NJ Cape May                 13283.906769                    NaN
#
# GRP2                 Other federal  Other local govt        Private  \
# GRP1
# 34001 NJ Atlantic      3570.939143               NaN   73625.650784
# 34003 NJ Bergen                NaN               NaN    4679.383252
# 34005 NJ Burlington            NaN               NaN  105640.324309
# 34007 NJ Camden                NaN               NaN   10105.600176
# 34009 NJ Cape May              NaN               NaN   16646.761715
#
# GRP2                         State
# GRP1
# 34001 NJ Atlantic     59465.501250
# 34003 NJ Bergen        9931.613594
# 34005 NJ Burlington  143446.556135
# 34007 NJ Camden       10918.013029
# 34009 NJ Cape May     30521.426453

# %%
df = df.reset_index()

# %%
#df.columns = df.columns.to_flat_index()

df = df.rename(columns = {"GRP1" : "County code and name"})

# %%
df.head()
# Out:
# GRP2 County code and name  County and Municipal  Dept of Defense  \
# 0       34001 NJ Atlantic          46432.619674              NaN
# 1         34003 NJ Bergen           3233.604712              NaN
# 2     34005 NJ Burlington          10965.412506     19626.162081
# 3         34007 NJ Camden          20728.499223              NaN
# 4       34009 NJ Cape May            300.403451              NaN
#
# GRP2  Fish and Wildlife Service  National Park Service  Other federal  \
# 0                    506.868805                    NaN    3570.939143
# 1                           NaN                    NaN            NaN
# 2                           NaN                    NaN            NaN
# 3                           NaN                    NaN            NaN
# 4                  13283.906769                    NaN            NaN
#
# GRP2  Other local govt        Private          State
# 0                  NaN   73625.650784   59465.501250
# 1                  NaN    4679.383252    9931.613594
# 2                  NaN  105640.324309  143446.556135
# 3                  NaN   10105.600176   10918.013029
# 4                  NaN   16646.761715   30521.426453

# %%
df.index = df.index.rename("")
df.columns = [''.join(str(s) for s in col if s) for col in df.columns]

# %%
#round numbers
#add total row
#add total column
#change NaN to -
#Change grp1 = county code and name

df.head()
# Out:
#   County code and name  County and Municipal  Dept of Defense  \
#
# 0    34001 NJ Atlantic          46432.619674              NaN
# 1      34003 NJ Bergen           3233.604712              NaN
# 2  34005 NJ Burlington          10965.412506     19626.162081
# 3      34007 NJ Camden          20728.499223              NaN
# 4    34009 NJ Cape May            300.403451              NaN
#
#    Fish and Wildlife Service  National Park Service  Other federal  \
#
# 0                 506.868805                    NaN    3570.939143
# 1                        NaN                    NaN            NaN
# 2                        NaN                    NaN            NaN
# 3                        NaN                    NaN            NaN
# 4               13283.906769                    NaN            NaN
#
#    Other local govt        Private          State
#
# 0               NaN   73625.650784   59465.501250
# 1               NaN    4679.383252    9931.613594
# 2               NaN  105640.324309  143446.556135
# 3               NaN   10105.600176   10918.013029
# 4               NaN   16646.761715   30521.426453

# %%
df = df[["County code and name","National Park Service","Fish and Wildlife Service","Dept of Defense","Other federal","State","County and Municipal","Other local govt","Private"]]

# %%
df.head()
# Out:
#   County code and name  National Park Service  Fish and Wildlife Service  \
#
# 0    34001 NJ Atlantic                    NaN                 506.868805
# 1      34003 NJ Bergen                    NaN                        NaN
# 2  34005 NJ Burlington                    NaN                        NaN
# 3      34007 NJ Camden                    NaN                        NaN
# 4    34009 NJ Cape May                    NaN               13283.906769
#
#    Dept of Defense  Other federal          State  County and Municipal  \
#
# 0              NaN    3570.939143   59465.501250          46432.619674
# 1              NaN            NaN    9931.613594           3233.604712
# 2     19626.162081            NaN  143446.556135          10965.412506
# 3              NaN            NaN   10918.013029          20728.499223
# 4              NaN            NaN   30521.426453            300.403451
#
#    Other local govt        Private
#
# 0               NaN   73625.650784
# 1               NaN    4679.383252
# 2               NaN  105640.324309
# 3               NaN   10105.600176
# 4               NaN   16646.761715

# %%
df = df.style.hide(axis = "index")

# %%
df
# Out:
# <style type="text/css">
# </style>
# <table id="T_ef6dc">
#   <thead>
#     <tr>
#       <th id="T_ef6dc_level0_col0" class="col_heading level0 col0" >County code and name</th>
#       <th id="T_ef6dc_level0_col1" class="col_heading level0 col1" >National Park Service</th>
#       <th id="T_ef6dc_level0_col2" class="col_heading level0 col2" >Fish and Wildlife Service</th>
#       <th id="T_ef6dc_level0_col3" class="col_heading level0 col3" >Dept of Defense</th>
#       <th id="T_ef6dc_level0_col4" class="col_heading level0 col4" >Other federal</th>
#       <th id="T_ef6dc_level0_col5" class="col_heading level0 col5" >State</th>
#       <th id="T_ef6dc_level0_col6" class="col_heading level0 col6" >County and Municipal</th>
#       <th id="T_ef6dc_level0_col7" class="col_heading level0 col7" >Other local govt</th>
#       <th id="T_ef6dc_level0_col8" class="col_heading level0 col8" >Private</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ef6dc_row0_col0" class="data row0 col0" >34001 NJ Atlantic</td>
#       <td id="T_ef6dc_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_ef6dc_row0_col2" class="data row0 col2" >506.868805</td>
#       <td id="T_ef6dc_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_ef6dc_row0_col4" class="data row0 col4" >3570.939143</td>
#       <td id="T_ef6dc_row0_col5" class="data row0 col5" >59465.501250</td>
#       <td id="T_ef6dc_row0_col6" class="data row0 col6" >46432.619674</td>
#       <td id="T_ef6dc_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_ef6dc_row0_col8" class="data row0 col8" >73625.650784</td>
#     </tr>
#     <tr>
#       <td id="T_ef6dc_row1_col0" class="data row1 col0" >34003 NJ Bergen</td>
#       <td id="T_ef6dc_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_ef6dc_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_ef6dc_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_ef6dc_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_ef6dc_row1_col5" class="data row1 col5" >9931.613594</td>
#       <td id="T_ef6dc_row1_col6" class="data row1 col6" >3233.604712</td>
#       <td id="T_ef6dc_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_ef6dc_row1_col8" class="data row1 col8" >4679.383252</td>
#     </tr>
#     <tr>
#       <td id="T_ef6dc_row2_col0" class="data row2 col0" >34005 NJ Burlington</td>
#       <td id="T_ef6dc_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_ef6dc_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_ef6dc_row2_col3" class="data row2 col3" >19626.162081</td>
#       <td id="T_ef6dc_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_ef6dc_row2_col5" class="data row2 col5" >143446.556135</td>
#       <td id="T_ef6dc_row2_col6" class="data row2 col6" >10965.412506</td>
#       <td id="T_ef6dc_row2_col7" class="data row2 col7" >nan</td>
#       <td id="T_ef6dc_row2_col8" class="data row2 col8" >105640.324309</td>
#     </tr>
#     <tr>
#       <td id="T_ef6dc_row3_col0" class="data row3 col0" >34007 NJ Camden</td>
#       <td id="T_ef6dc_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_ef6dc_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_ef6dc_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_ef6dc_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_ef6dc_row3_col5" class="data row3 col5" >10918.013029</td>
#       <td id="T_ef6dc_row3_col6" class="data row3 col6" >20728.499223</td>
#       <td id="T_ef6dc_row3_col7" class="data row3 col7" >nan</td>
#       <td id="T_ef6dc_row3_col8" class="data row3 col8" >10105.600176</td>
#     </tr>
#     <tr>
#       <td id="T_ef6dc_row4_col0" class="data row4 col0" >34009 NJ Cape May</td>
#       <td id="T_ef6dc_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_ef6dc_row4_col2" class="data row4 col2" >13283.906769</td>
#       <td id="T_ef6dc_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_ef6dc_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_ef6dc_row4_col5" class="data row4 col5" >30521.426453</td>
#       <td id="T_ef6dc_row4_col6" class="data row4 col6" >300.403451</td>
#       <td id="T_ef6dc_row4_col7" class="data row4 col7" >nan</td>
#       <td id="T_ef6dc_row4_col8" class="data row4 col8" >16646.761715</td>
#     </tr>
#     <tr>
#       <td id="T_ef6dc_row5_col0" class="data row5 col0" >34011 NJ Cumberland</td>
#       <td id="T_ef6dc_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_ef6dc_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_ef6dc_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_ef6dc_row5_col4" class="data row5 col4" >nan</td>
#       <td id="T_ef6dc_row5_col5" class="data row5 col5" >66973.090495</td>
#       <td id="T_ef6dc_row5_col6" class="data row5 col6" >8516.423980</td>
#       <td id="T_ef6dc_row5_col7" class="data row5 col7" >nan</td>
#       <td id="T_ef6dc_row5_col8" class="data row5 col8" >73311.952143</td>
#     </tr>
#     <tr>
#       <td id="T_ef6dc_row6_col0" class="data row6 col0" >34013 NJ Essex</td>
#       <td id="T_ef6dc_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_ef6dc_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_ef6dc_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_ef6dc_row6_col4" class="data row6 col4" >nan</td>
#       <td id="T_ef6dc_row6_col5" class="data row6 col5" >4348.589171</td>
#       <td id="T_ef6dc_row6_col6" class="data row6 col6" >3622.860777</td>
#       <td id="T_ef6dc_row6_col7" class="data row6 col7" >nan</td>
#       <td id="T_ef6dc_row6_col8" class="data row6 col8" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_ef6dc_row7_col0" class="data row7 col0" >34015 NJ Gloucester</td>
#       <td id="T_ef6dc_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_ef6dc_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_ef6dc_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_ef6dc_row7_col4" class="data row7 col4" >3177.762804</td>
#       <td id="T_ef6dc_row7_col5" class="data row7 col5" >2856.194620</td>
#       <td id="T_ef6dc_row7_col6" class="data row7 col6" >5544.611276</td>
#       <td id="T_ef6dc_row7_col7" class="data row7 col7" >nan</td>
#       <td id="T_ef6dc_row7_col8" class="data row7 col8" >49994.386300</td>
#     </tr>
#     <tr>
#       <td id="T_ef6dc_row8_col0" class="data row8 col0" >34017 NJ Hudson</td>
#       <td id="T_ef6dc_row8_col1" class="data row8 col1" >nan</td>
#       <td id="T_ef6dc_row8_col2" class="data row8 col2" >nan</td>
#       <td id="T_ef6dc_row8_col3" class="data row8 col3" >nan</td>
#       <td id="T_ef6dc_row8_col4" class="data row8 col4" >nan</td>
#       <td id="T_ef6dc_row8_col5" class="data row8 col5" >1517.090791</td>
#       <td id="T_ef6dc_row8_col6" class="data row8 col6" >nan</td>
#       <td id="T_ef6dc_row8_col7" class="data row8 col7" >nan</td>
#       <td id="T_ef6dc_row8_col8" class="data row8 col8" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_ef6dc_row9_col0" class="data row9 col0" >34019 NJ Hunterdon</td>
#       <td id="T_ef6dc_row9_col1" class="data row9 col1" >nan</td>
#       <td id="T_ef6dc_row9_col2" class="data row9 col2" >nan</td>
#       <td id="T_ef6dc_row9_col3" class="data row9 col3" >nan</td>
#       <td id="T_ef6dc_row9_col4" class="data row9 col4" >nan</td>
#       <td id="T_ef6dc_row9_col5" class="data row9 col5" >9898.998646</td>
#       <td id="T_ef6dc_row9_col6" class="data row9 col6" >9505.545680</td>
#       <td id="T_ef6dc_row9_col7" class="data row9 col7" >nan</td>
#       <td id="T_ef6dc_row9_col8" class="data row9 col8" >66653.027001</td>
#     </tr>
#     <tr>
#       <td id="T_ef6dc_row10_col0" class="data row10 col0" >34021 NJ Mercer</td>
#       <td id="T_ef6dc_row10_col1" class="data row10 col1" >nan</td>
#       <td id="T_ef6dc_row10_col2" class="data row10 col2" >nan</td>
#       <td id="T_ef6dc_row10_col3" class="data row10 col3" >nan</td>
#       <td id="T_ef6dc_row10_col4" class="data row10 col4" >nan</td>
#       <td id="T_ef6dc_row10_col5" class="data row10 col5" >1480.399044</td>
#       <td id="T_ef6dc_row10_col6" class="data row10 col6" >9240.381497</td>
#       <td id="T_ef6dc_row10_col7"
